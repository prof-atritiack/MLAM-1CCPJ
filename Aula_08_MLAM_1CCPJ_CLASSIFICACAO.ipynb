# %% [markdown]
# <a href="https://colab.research.google.com/github/prof-atritiack/MLAM-1CCPJ/blob/main/Aula_08_MLAM_1CCPJ_CLASSIFICACAO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
# KNN
from sklearn.neighbors import KNeighborsClassifier
# Logistic Regression
from sklearn.linear_model import LogisticRegression
# Acurácia e matriz de confusão
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
dados = pd.read_csv('https://raw.githubusercontent.com/prof-atritiack/MLAM-1CCPJ/refs/heads/main/datasets_/occupancy%2Bdetection1/datatraining.txt')
dados.head(20)
# Out:
#     index                 date  ...  HumidityRatio  Occupancy
# 0       1  2015-02-04 17:51:00  ...       0.004793          1
# 1       2  2015-02-04 17:51:59  ...       0.004783          1
# 2       3  2015-02-04 17:53:00  ...       0.004779          1
# 3       4  2015-02-04 17:54:00  ...       0.004772          1
# 4       5  2015-02-04 17:55:00  ...       0.004757          1
# 5       6  2015-02-04 17:55:59  ...       0.004757          1
# 6       7  2015-02-04 17:57:00  ...       0.004757          1
# 7       8  2015-02-04 17:57:59  ...       0.004757          1
# 8       9  2015-02-04 17:58:59  ...       0.004757          1
# 9      10  2015-02-04 18:00:00  ...       0.004745          1
# 10     11  2015-02-04 18:01:00  ...       0.004741          1
# 11     12  2015-02-04 18:02:00  ...       0.004739          1
# 12     13  2015-02-04 18:03:00  ...       0.004751          1
# 13     14  2015-02-04 18:04:00  ...       0.004734          1
# ...

# %%
# target (y) ---> Occupancy
# features (X) ---> todas, exceto index, date e Occupancy
